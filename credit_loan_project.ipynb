# %%
import pandas as pd 
import numpy as np

# %%
path='C:\\Users\goswa\\OneDrive\\Documents\\PYHTON\\Micro Credit Project\\Data file.csv'
df= pd.read_csv(path)
df
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 0                1      0  21408I70789   272.0   3055.050000   3065.150000
# 1                2      1  76462I70374   712.0  12122.000000  12124.750000
# 2                3      1  17943I70372   535.0   1398.000000   1398.000000
# 3                4      1  55773I70781   241.0     21.228000     21.228000
# 4                5      1  03813I82730   947.0    150.619333    150.619333
# ...            ...    ...          ...     ...           ...           ...
# 209588      209589      1  22758I85348   404.0    151.872333    151.872333
# 209589      209590      1  95583I84455  1075.0     36.936000     36.936000
# 209590      209591      1  28556I85350  1013.0  11843.111667  11904.350000
# 209591      209592      1  59712I82733  1732.0  12488.228333  12574.370000
# 209592      209593      1  65061I85339  1581.0   4489.362000   4534.820000
#
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  label       msisdn    aon  daily_decr30  daily_decr90  \
# 0           1      0  21408I70789  272.0   3055.050000   3065.150000
# 1           2      1  76462I70374  712.0  12122.000000  12124.750000
# 2           3      1  17943I70372  535.0   1398.000000   1398.000000
# 3           4      1  55773I70781  241.0     21.228000     21.228000
# 4           5      1  03813I82730  947.0    150.619333    150.619333
#
#    rental30  rental90  last_rech_date_ma  last_rech_date_da  ...  \
# 0    220.13    260.13                2.0                0.0  ...
# 1   3691.26   3691.26               20.0                0.0  ...
# 2    900.13    900.13                3.0                0.0  ...
# 3    159.42    159.42               41.0                0.0  ...
# 4   1098.90   1098.90                4.0                0.0  ...
#
#    maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# 0              6.0                 0.0          2.0            12
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 0                1      0  21408I70789   272.0   3055.050000   3065.150000
# 1                2      1  76462I70374   712.0  12122.000000  12124.750000
# 2                3      1  17943I70372   535.0   1398.000000   1398.000000
# 3                4      1  55773I70781   241.0     21.228000     21.228000
# 4                5      1  03813I82730   947.0    150.619333    150.619333
# ...            ...    ...          ...     ...           ...           ...
# 209588      209589      1  22758I85348   404.0    151.872333    151.872333
# 209589      209590      1  95583I84455  1075.0     36.936000     36.936000
# 209590      209591      1  28556I85350  1013.0  11843.111667  11904.350000
# 209591      209592      1  59712I82733  1732.0  12488.228333  12574.370000
# 209592      209593      1  65061I85339  1581.0   4489.362000   4534.820000
#
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0              0
# label                   0
# msisdn                  0
# aon                     0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# fr_da_rech30            0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# ...

# %% [markdown]
# No nul values in the dataset.

# %%
df.shape
# Out:
# (209593, 37)

# %%
df.dtypes
# Out:
# Unnamed: 0                int64
# label                     int64
# msisdn                   object
# aon                     float64
# daily_decr30            float64
# daily_decr90            float64
# rental30                float64
# rental90                float64
# last_rech_date_ma       float64
# last_rech_date_da       float64
# last_rech_amt_ma          int64
# cnt_ma_rech30             int64
# fr_ma_rech30            float64
# sumamnt_ma_rech30       float64
# medianamnt_ma_rech30    float64
# medianmarechprebal30    float64
# cnt_ma_rech90             int64
# fr_ma_rech90              int64
# sumamnt_ma_rech90         int64
# medianamnt_ma_rech90    float64
# medianmarechprebal90    float64
# cnt_da_rech30           float64
# fr_da_rech30            float64
# cnt_da_rech90             int64
# fr_da_rech90              int64
# cnt_loans30               int64
# amnt_loans30              int64
# maxamnt_loans30         float64
# medianamnt_loans30      float64
# ...

# %%
df.describe()
# Out:
#           Unnamed: 0          label            aon   daily_decr30  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean   104797.000000       0.875177    8112.343445    5381.402289
# std     60504.431823       0.330519   75696.082531    9220.623400
# min         1.000000       0.000000     -48.000000     -93.012667
# 25%     52399.000000       1.000000     246.000000      42.440000
# 50%    104797.000000       1.000000     527.000000    1469.175667
# 75%    157195.000000       1.000000     982.000000    7244.000000
# max    209593.000000       1.000000  999860.755168  265926.000000
#
#         daily_decr90       rental30       rental90  last_rech_date_ma  \
# count  209593.000000  209593.000000  209593.000000      209593.000000
# mean     6082.515068    2692.581910    3483.406534        3755.847800
# std     10918.812767    4308.586781    5770.461279       53905.892230
# min       -93.012667  -23737.140000  -24720.580000         -29.000000
# ...

# %% [markdown]
# OBSERVING THE STD VALUES IT CAN BE SEEN THAT THE DATASET CONTAINS OUTLIERS.

# %% [markdown]
# #### FINDING THE CORRELATIONS AMONG THE VALUES

# %%
cor=df.corr()
cor
# Out:
#                       Unnamed: 0     label       aon  daily_decr30  \
# Unnamed: 0              1.000000  0.000403 -0.002048      0.002739
# label                   0.000403  1.000000 -0.003785      0.168298
# aon                    -0.002048 -0.003785  1.000000      0.001104
# daily_decr30            0.002739  0.168298  0.001104      1.000000
# daily_decr90            0.003077  0.166150  0.000374      0.977704
# rental30               -0.003906  0.058085 -0.000960      0.442066
# rental90               -0.003459  0.075521 -0.000790      0.458977
# last_rech_date_ma      -0.001853  0.003728  0.001692      0.000487
# last_rech_date_da      -0.001133  0.001711 -0.001693     -0.001636
# last_rech_amt_ma       -0.001064  0.131804  0.004256      0.275837
# cnt_ma_rech30           0.003320  0.237331 -0.003148      0.451385
# fr_ma_rech30            0.003181  0.001330 -0.001163     -0.000577
# sumamnt_ma_rech30       0.000123  0.202828  0.000707      0.636536
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings 
warnings.filterwarnings('ignore')

# %%
sns.countplot(df['label'])
# Out:
# <AxesSubplot:xlabel='label', ylabel='count'>

# %% [markdown]
# It can be seen that the number of users paying back the loans to the bank is more than the people not paying back the loan.
# It can also be seen that the column 'label' has "Class Imbalance"

# %%
df['label'].value_counts()
# Out:
# 1    183431
# 0     26162
# Name: label, dtype: int64

# %%
# !pip install imblearn

# %%
plt.figure(figsize=(30,20))
sns.heatmap(cor.corr(), annot =True, vmin=-1, vmax=1)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Ploting correlations data via heatmap is not enough as the number dataset is huge.

# %%
cor_mat=df.corr()
cor_mat['label'].sort_values(ascending=False)
# Out:
# label                   1.000000
# cnt_ma_rech30           0.237331
# cnt_ma_rech90           0.236392
# sumamnt_ma_rech90       0.205793
# sumamnt_ma_rech30       0.202828
# amnt_loans90            0.199788
# amnt_loans30            0.197272
# cnt_loans30             0.196283
# daily_decr30            0.168298
# daily_decr90            0.166150
# medianamnt_ma_rech30    0.141490
# last_rech_amt_ma        0.131804
# medianamnt_ma_rech90    0.120855
# fr_ma_rech90            0.084385
# maxamnt_loans90         0.084144
# rental90                0.075521
# rental30                0.058085
# payback90               0.049183
# payback30               0.048336
# medianamnt_loans30      0.044589
# medianmarechprebal90    0.039300
# medianamnt_loans90      0.035747
# cnt_loans90             0.004733
# cnt_da_rech30           0.003827
# last_rech_date_ma       0.003728
# cnt_da_rech90           0.002999
# last_rech_date_da       0.001711
# fr_ma_rech30            0.001330
# ...

# %% [markdown]
# It can bee seen that the correlation among the label and the independent variables is low, with  the hihgest correlation among the data being 0.237331 and the lowest being -0.005418.

# %%
df.iloc[:,3:9].boxplot(figsize=[20,40])
plt.subplots_adjust(bottom=0.05)
plt.show()

# %%
df.iloc[:,9:15].boxplot(figsize=[20,40])
plt.subplots_adjust(bottom=0.05)
plt.show()

# %%
df.iloc[:,15:21].boxplot(figsize=[20,40])
plt.subplots_adjust(bottom=0.05)
plt.show()

# %%
df.iloc[:,21:27].boxplot(figsize=[20,40])
plt.subplots_adjust(bottom=0.05)
plt.show()

# %%
df.iloc[:,27:37].boxplot(figsize=[20,40])
plt.subplots_adjust(bottom=0.05)
plt.show()

# %%
df.drop(['msisdn'], axis=1, inplace =True)

# %%
df.drop(['pcircle'], axis=1, inplace= True)

# %%
df.drop(['pdate'], axis=1, inplace=True)

# %% [markdown]
# ### Removing outliers

# %%
from scipy.stats import zscore

z=np.abs(zscore(df))
print(z)
# Out:
# [[1.73204254 2.64789583 0.10357685 ... 0.22959366 2.9046997  2.39409346]
#  [1.73202602 0.37765836 0.09776412 ... 0.22959366 0.38562959 0.41923266]
#  [1.73200949 0.37765836 0.10010243 ... 0.22959366 0.38562959 0.41923266]
#  ...
#  [1.73200949 0.37765836 0.09378769 ... 0.22959366 0.06820893 0.04735622]
#  [1.73202602 0.37765836 0.08428915 ... 0.22959366 0.38562959 0.59938541]
#  [1.73204254 0.37765836 0.08628398 ... 0.22959366 0.38562959 0.41923266]]

# %%
treshhold=3 
print (np.where(z<3))
df_new=df[(z<3).all(axis=1)]
print(df_new)
# Out:
# (array([     0,      0,      0, ..., 209592, 209592, 209592], dtype=int64), array([ 0,  1,  2, ..., 31, 32, 33], dtype=int64))
#         Unnamed: 0  label     aon  daily_decr30  daily_decr90  rental30  \
# 0                1      0   272.0   3055.050000   3065.150000    220.13
# 1                2      1   712.0  12122.000000  12124.750000   3691.26
# 2                3      1   535.0   1398.000000   1398.000000    900.13
# 3                4      1   241.0     21.228000     21.228000    159.42
# 4                5      1   947.0    150.619333    150.619333   1098.90
# ...            ...    ...     ...           ...           ...       ...
# 209588      209589      1   404.0    151.872333    151.872333   1089.19
# 209589      209590      1  1075.0     36.936000     36.936000   1728.36
# 209590      209591      1  1013.0  11843.111667  11904.350000   5861.83
# 209591      209592      1  1732.0  12488.228333  12574.370000    411.83
# ...

# %%
y=df['label']
y
# Out:
# 0         0
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 209588    1
# 209589    1
# 209590    1
# 209591    1
# 209592    1
# Name: label, Length: 209593, dtype: int64

# %%
x=df.drop(['label'], axis=1)
x
# Out:
#         Unnamed: 0     aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0                1   272.0   3055.050000   3065.150000    220.13    260.13
# 1                2   712.0  12122.000000  12124.750000   3691.26   3691.26
# 2                3   535.0   1398.000000   1398.000000    900.13    900.13
# 3                4   241.0     21.228000     21.228000    159.42    159.42
# 4                5   947.0    150.619333    150.619333   1098.90   1098.90
# ...            ...     ...           ...           ...       ...       ...
# 209588      209589   404.0    151.872333    151.872333   1089.19   1089.19
# 209589      209590  1075.0     36.936000     36.936000   1728.36   1728.36
# 209590      209591  1013.0  11843.111667  11904.350000   5861.83   8893.20
# 209591      209592  1732.0  12488.228333  12574.370000    411.83    984.58
# 209592      209593  1581.0   4489.362000   4534.820000    483.92    631.20
#
# ...

# %% [markdown]
# After removing outliers it can be seen that alomost 48000 rows and 3 columns have been removed. Which accounts to almost 23% of the data.

# %% [markdown]
# ### Balancing the Y values

# %%
from imblearn.over_sampling import SMOTE
SM=SMOTE()
X,Y= SM.fit_resample(x,y)
Y.value_counts()
# Out:
# 1    183431
# 0    183431
# Name: label, dtype: int64

# %% [markdown]
# Using the SMOTE() the dataset is balanced with equal no of values in 'Y'.

# %%
X.drop(['aon'], axis=1)
X
# Out:
#         Unnamed: 0          aon  daily_decr30  daily_decr90     rental30  \
# 0                1   272.000000   3055.050000   3065.150000   220.130000
# 1                2   712.000000  12122.000000  12124.750000  3691.260000
# 2                3   535.000000   1398.000000   1398.000000   900.130000
# 3                4   241.000000     21.228000     21.228000   159.420000
# 4                5   947.000000    150.619333    150.619333  1098.900000
# ...            ...          ...           ...           ...          ...
# 366857       46353  1220.899606      1.573823      1.573823     0.000000
# 366858      176776   976.218451   7814.486800   7829.591955  4749.268241
# 366859       60223   179.428653      0.000000      0.000000   664.899029
# 366860      118587   151.539503   1573.096185   1577.939992     0.000000
# 366861      119731   171.582966     11.576433     11.576433   400.244677
#
#            rental90  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  \
# ...

# %% [markdown]
# ### Training the data

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.4,random_state=42)

# %% [markdown]
# ### Data_scaling

# %%
from sklearn.preprocessing import MinMaxScaler
MM=MinMaxScaler()
MM_fit=MM.fit(X_train)
MM_train=MM_fit.transform(X_train)
MM_test=MM_fit.transform(X_test)
print(MM_train)
print(MM_test)
# Out:
# [[2.76925059e-01 7.57326704e-04 1.21303802e-03 ... 0.00000000e+00
#   5.24781341e-02 5.24781341e-02]
#  [2.13687611e-01 2.67115231e-04 3.27864019e-04 ... 0.00000000e+00
#   1.45772595e-02 1.45772595e-02]
#  [4.08500365e-01 3.25988960e-04 5.64571787e-03 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  ...
#  [6.29468823e-01 3.06132062e-04 1.40587165e-02 ... 0.00000000e+00
#   7.58017493e-02 7.58017493e-02]
#  [7.00726653e-01 2.81121273e-04 2.57449954e-04 ... 1.66666667e-01
#   0.00000000e+00 0.00000000e+00]
#  [5.81880901e-01 4.00172631e-04 2.18123534e-04 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]]
# [[9.01560659e-01 1.11650457e-03 1.94688687e-02 ... 0.00000000e+00
#   1.42980088e-01 1.42980088e-01]
#  [8.75476523e-01 4.90211473e-05 7.37353898e-03 ... 3.33333333e-01
#   0.00000000e+00 0.00000000e+00]
#  [2.59381367e-01 7.90340946e-04 8.00667943e-02 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  ...
# ...

# %%
from sklearn.tree import DecisionTreeClassifier 
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix , classification_report

# %%
from sklearn.svm import LinearSVC

clf = LinearSVC(random_state=0, tol=1e-5)

clf.fit(X_train, Y_train.ravel()) 
clf.score(X_train,Y_train)
pred_clf=clf.predict(X_test)
print(accuracy_score(Y_test,pred_clf))
print(confusion_matrix(Y_test,pred_clf))
print(classification_report(Y_test, pred_clf))
# Out:
# 0.6010562540461345
# [[25792 47605]
#  [10938 62410]]
#               precision    recall  f1-score   support
#
#            0       0.70      0.35      0.47     73397
#            1       0.57      0.85      0.68     73348
#
#     accuracy                           0.60    146745
#    macro avg       0.63      0.60      0.57    146745
# weighted avg       0.63      0.60      0.57    146745

# %% [markdown]
# SVM gives an accuracy score - 67% , which low in comparision to decision tree / kneighbors / logistic regression or the auc_roc score.

# %%
dtc=DecisionTreeClassifier()
dtc.fit(X_train,Y_train)
dtc.score(X_train,Y_train)
pred_dtc=dtc.predict(X_test)
print(accuracy_score(Y_test,pred_dtc))
print(confusion_matrix(Y_test,pred_dtc))
print(classification_report(Y_test, pred_dtc))
# Out:
# 0.8857201267504855
# [[65410  7987]
#  [ 8783 64565]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.89      0.89     73397
#            1       0.89      0.88      0.89     73348
#
#     accuracy                           0.89    146745
#    macro avg       0.89      0.89      0.89    146745
# weighted avg       0.89      0.89      0.89    146745

# %% [markdown]
# Decision tree score of 89% accuracy

# %%
from sklearn.linear_model import LogisticRegression

lg=LogisticRegression()
lg.fit(X_train,Y_train)
Y_pred=lg.predict(X_test)
print(Y_pred)
print(accuracy_score(Y_test,Y_pred))
print(confusion_matrix(Y_test,Y_pred))
print(classification_report(Y_test,Y_pred))
# Out:
# C:\Users\goswa\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [0 0 1 ... 1 0 0]
# 0.7368087498722273
# [[59945 13452]
#  [25170 48178]]
#               precision    recall  f1-score   support
#
#            0       0.70      0.82      0.76     73397
#            1       0.78      0.66      0.71     73348
#
#     accuracy                           0.74    146745
#    macro avg       0.74      0.74      0.74    146745
# weighted avg       0.74      0.74      0.74    146745

# %% [markdown]
# LogisticRegression gives a score of -  74%

# %%
knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train,Y_train)
knn.score(X_train,Y_train)
pred_knn=knn.predict(X_test)
print(accuracy_score(Y_test,pred_knn))
print(confusion_matrix(Y_test,pred_knn))
print(classification_report(Y_test, pred_knn))
# Out:
# 0.8454257385260145
# [[70472  2925]
#  [19758 53590]]
#               precision    recall  f1-score   support
#
#            0       0.78      0.96      0.86     73397
#            1       0.95      0.73      0.83     73348
#
#     accuracy                           0.85    146745
#    macro avg       0.86      0.85      0.84    146745
# weighted avg       0.86      0.85      0.84    146745

# %% [markdown]
# Kneighbors classifiers score -  84%

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_squared_error

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import auc

# %%
false_positive_rate , true_positive_rate ,threshold = roc_curve(Y_test,Y_pred)
roc_auc= auc(false_positive_rate , true_positive_rate)
roc_auc
# Out:
# 0.7367820566684677

# %%
tpr=true_positive_rate
fpr=false_positive_rate
print(tpr,fpr,threshold)
# Out:
# [0.         0.65684136 1.        ] [0.         0.18327725 1.        ] [2 1 0]

# %%
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,label='Logistic Regression')
plt.xlabel('false_positive_rate')
plt.ylabel('true_positive_rate')
plt.title('Logistic Regression')
plt.show()

# %%
auc_score=roc_auc_score(Y_test,lg.predict(X_test))
print(auc_score)
# Out:
# 0.7367820566684677

# %% [markdown]
# auc_roc score - 73%
# it is interesting to observe that the Decision tree score is better than the auc_roc score.

# %%
rf= RandomForestClassifier()
rf.fit(X_train,Y_train)
train_score=rf.score(X_train,Y_train)
test_score=rf.score(X_test, Y_test)
MSE= mean_squared_error(Y_test,Y_pred)
RMSE= np.sqrt(MSE)
print('train_score:' , train_score)
print('mean_squared_error :' , MSE)
print('root_mean_squared_error :' , RMSE)
print('test_score:' , test_score)
# Out:
# train_score: 0.9999909139230501
# mean_squared_error : 0.26319125012777267
# root_mean_squared_error : 0.513021685826021
# test_score: 0.9334355514668302

# %%
X_predict = list(rf.predict(X_test))
df_new = {'predicted':X_predict,'orignal':Y_test}
pd.DataFrame(df_new).head(10)
# Out:
#         predicted  orignal
# 323513          0        0
# 183493          1        1
# 54365           1        1
# 81520           1        1
# 225323          0        0
# 36484           1        1
# 356836          0        0
# 344264          0        0
# 219523          0        0
# 76507           1        1

# %% [markdown]
# ### IT IS VISIBLE THAT THE RANDOM FOREST CLASSIFIER PREDICTED VALUES COINCIDE WITH THE REAL VALUES.

# %% [markdown]
# ### RANDOM FOREST- 93%

# %% [markdown]
# ### DECISION TREE - 89%

# %% [markdown]
# ### KNEIGHBORS- 84%

# %% [markdown]
# ### LOGISTIC REGRESSION - 74%

# %% [markdown]
# ### AUC_ROC - 73%

# %% [markdown]
# ### SVM - 67%

# %% [markdown]
# ## IT IS CLEARLY VISIBLE THAT THE PREFFERED CLASSIFIER WITH HIGHEST PREDICTIVE RATES IS THE RANDOM FOREST  WITH 93% ACCURACY AND LOWEST ERROR VALUES.
